# %% [markdown]
# # Ungraded Lab: Build a Multi-output Model
#
# In this lab, we'll show how you can build models with more than one output. The dataset we will be working on is available from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Energy+efficiency). It is an Energy Efficiency dataset which uses the bulding features (e.g. wall area, roof area) as inputs and has two outputs: Cooling Load and Heating Load. Let's see how we can build a model to train on this data.

# %% [markdown]
# ## Imports

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Utilities
#
# We define a few utilities for data conversion and visualization to make our code more neat.

# %%
def format_output(data):
    y1 = data.pop('Y1')
    y1 = np.array(y1)
    y2 = data.pop('Y2')
    y2 = np.array(y2)
    return y1, y2


def norm(x):
    return (x - train_stats['mean']) / train_stats['std']


def plot_diff(y_true, y_pred, title=''):
    plt.scatter(y_true, y_pred)
    plt.title(title)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.axis('equal')
    plt.axis('square')
    plt.xlim(plt.xlim())
    plt.ylim(plt.ylim())
    plt.plot([-100, 100], [-100, 100])
    plt.show()


def plot_metrics(metric_name, title, ylim=5):
    plt.title(title)
    plt.ylim(0, ylim)
    plt.plot(history.history[metric_name], color='blue', label=metric_name)
    plt.plot(history.history['val_' + metric_name], color='green', label='val_' + metric_name)
    plt.show()

# %% [markdown]
# ## Prepare the Data
#
# We download the dataset and format it for training.

# %%
# Specify data URI
URI = './data/ENB2012_data.xlsx'

# Use pandas excel reader
df = pd.read_excel(URI)
df = df.sample(frac=1).reset_index(drop=True)

# Split the data into train and test with 80 train / 20 test
train, test = train_test_split(df, test_size=0.2)
train_stats = train.describe()

# Get Y1 and Y2 as the 2 outputs and format them as np arrays
train_stats.pop('Y1')
train_stats.pop('Y2')
train_stats = train_stats.transpose()
train_Y = format_output(train)
test_Y = format_output(test)

# Normalize the training and test data
norm_train_X = norm(train)
norm_test_X = norm(test)

# %% [markdown]
# ## Build the Model
#
# Here is how we'll build the model using the functional syntax. Notice that we can specify a list of outputs (i.e. `[y1_output, y2_output]`) when we instantiate the `Model()` class.

# %%
# Define model layers.
input_layer = Input(shape=(len(train .columns),))
first_dense = Dense(units='128', activation='relu')(input_layer)
second_dense = Dense(units='128', activation='relu')(first_dense)

# Y1 output will be fed directly from the second dense
y1_output = Dense(units='1', name='y1_output')(second_dense)
third_dense = Dense(units='64', activation='relu')(second_dense)

# Y2 output will come via the third dense
y2_output = Dense(units='1', name='y2_output')(third_dense)

# Define the model with the input layer and a list of output layers
model = Model(inputs=input_layer, outputs=[y1_output, y2_output])

print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 8)]          0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          1152        input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128)          16512       dense[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           8256        dense_1[0][0]
# __________________________________________________________________________________________________
# y1_output (Dense)               (None, 1)            129         dense_1[0][0]
# __________________________________________________________________________________________________
# y2_output (Dense)               (None, 1)            65          dense_2[0][0]
# ==================================================================================================
# Total params: 26,114
# Trainable params: 26,114
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# ## Configure parameters
#
# We specify the optimizer as well as the loss and metrics for each output.

# %%
# Specify the optimizer, and compile the model with loss functions for both outputs
optimizer = tf.keras.optimizers.SGD(lr=0.001)
model.compile(optimizer=optimizer,
              loss={'y1_output': 'mse', 'y2_output': 'mse'},
              metrics={'y1_output': tf.keras.metrics.RootMeanSquaredError(),
                       'y2_output': tf.keras.metrics.RootMeanSquaredError()})

# %% [markdown]
# ## Train the Model

# %%
# Train the model for 500 epochs
history = model.fit(norm_train_X, train_Y,
                    epochs=500, batch_size=10, validation_data=(norm_test_X, test_Y))
# Out:
# Train on 614 samples, validate on 154 samples
# Epoch 1/500
# 614/614 [==============================] - 1s 937us/sample - loss: 220.4180 - y1_output_loss: 105.7590 - y2_output_loss: 112.6727 - y1_output_root_mean_squared_error: 10.3298 - y2_output_root_mean_squared_error: 10.6636 - val_loss: 36.0773 - val_y1_output_loss: 14.7752 - val_y2_output_loss: 20.1002 - val_y1_output_root_mean_squared_error: 3.9091 - val_y2_output_root_mean_squared_error: 4.5603
# Epoch 2/500
# 614/614 [==============================] - 0s 156us/sample - loss: 29.2671 - y1_output_loss: 12.0133 - y2_output_loss: 17.1055 - y1_output_root_mean_squared_error: 3.4777 - y2_output_root_mean_squared_error: 4.1440 - val_loss: 26.2806 - val_y1_output_loss: 11.2715 - val_y2_output_loss: 14.3629 - val_y1_output_root_mean_squared_error: 3.4008 - val_y2_output_root_mean_squared_error: 3.8360
# Epoch 3/500
# 614/614 [==============================] - 0s 129us/sample - loss: 25.4686 - y1_output_loss: 10.0958 - y2_output_loss: 15.2015 - y1_output_root_mean_squared_error: 3.1825 - y2_output_root_mean_squared_error: 3.9167 - val_loss: 39.9514 - val_y1_output_loss: 14.0189 - val_y2_output_loss: 24.5258 - val_y1_output_root_mean_squared_error: 3.8077 - val_y2_output_root_mean_squared_error: 5.0451
# Epoch 4/500
# 614/614 [==============================] - 0s 139us/sample - loss: 23.2667 - y1_output_loss: 9.0316 - y2_output_loss: 14.0994 - y1_output_root_mean_squared_error: 3.0150 - y2_output_root_mean_squared_error: 3.7651 - val_loss: 24.2838 - val_y1_output_loss: 9.9438 - val_y2_output_loss: 13.5552 - val_y1_output_root_mean_squared_error: 3.2037 - val_y2_output_root_mean_squared_error: 3.7443
# Epoch 5/500
# 614/614 [==============================] - 0s 137us/sample - loss: 26.5720 - y1_output_loss: 9.2864 - y2_output_loss: 17.2136 - y1_output_root_mean_squared_error: 3.0534 - y2_output_root_mean_squared_error: 4.1532 - val_loss: 27.2097 - val_y1_output_loss: 9.5822 - val_y2_output_loss: 16.9371 - val_y1_output_root_mean_squared_error: 3.1432 - val_y2_output_root_mean_squared_error: 4.1629
# Epoch 6/500
# 614/614 [==============================] - 0s 139us/sample - loss: 23.6802 - y1_output_loss: 8.8503 - y2_output_loss: 14.6254 - y1_output_root_mean_squared_error: 2.9855 - y2_output_root_mean_squared_error: 3.8428 - val_loss: 24.3265 - val_y1_output_loss: 9.6256 - val_y2_output_loss: 13.9569 - val_y1_output_root_mean_squared_error: 3.1484 - val_y2_output_root_mean_squared_error: 3.7966
# Epoch 7/500
# 614/614 [==============================] - 0s 139us/sample - loss: 20.1475 - y1_output_loss: 8.0166 - y2_output_loss: 11.9610 - y1_output_root_mean_squared_error: 2.8436 - y2_output_root_mean_squared_error: 3.4730 - val_loss: 22.5489 - val_y1_output_loss: 9.3898 - val_y2_output_loss: 12.3610 - val_y1_output_root_mean_squared_error: 3.1186 - val_y2_output_root_mean_squared_error: 3.5810
# Epoch 8/500
# 614/614 [==============================] - 0s 137us/sample - loss: 21.2341 - y1_output_loss: 8.5078 - y2_output_loss: 13.0014 - y1_output_root_mean_squared_error: 2.9012 - y2_output_root_mean_squared_error: 3.5801 - val_loss: 42.5725 - val_y1_output_loss: 13.6092 - val_y2_output_loss: 27.4473 - val_y1_output_root_mean_squared_error: 3.7521 - val_y2_output_root_mean_squared_error: 5.3380
# Epoch 9/500
# 614/614 [==============================] - 0s 140us/sample - loss: 20.1714 - y1_output_loss: 7.5730 - y2_output_loss: 12.4309 - y1_output_root_mean_squared_error: 2.7619 - y2_output_root_mean_squared_error: 3.5417 - val_loss: 21.5370 - val_y1_output_loss: 8.3990 - val_y2_output_loss: 12.4515 - val_y1_output_root_mean_squared_error: 2.9404 - val_y2_output_root_mean_squared_error: 3.5904
# Epoch 10/500
# 614/614 [==============================] - 0s 128us/sample - loss: 21.4071 - y1_output_loss: 8.1440 - y2_output_loss: 13.7073 - y1_output_root_mean_squared_error: 2.8444 - y2_output_root_mean_squared_error: 3.6492 - val_loss: 82.6475 - val_y1_output_loss: 16.4247 - val_y2_output_loss: 63.5570 - val_y1_output_root_mean_squared_error: 4.1248 - val_y2_output_root_mean_squared_error: 8.1014
# Epoch 11/500
# 614/614 [==============================] - 0s 135us/sample - loss: 22.4087 - y1_output_loss: 8.0252 - y2_output_loss: 14.2243 - y1_output_root_mean_squared_error: 2.8439 - y2_output_root_mean_squared_error: 3.7843 - val_loss: 19.5461 - val_y1_output_loss: 8.2617 - val_y2_output_loss: 10.7998 - val_y1_output_root_mean_squared_error: 2.9145 - val_y2_output_root_mean_squared_error: 3.3244
# Epoch 12/500
# 614/614 [==============================] - 0s 137us/sample - loss: 17.5353 - y1_output_loss: 7.2823 - y2_output_loss: 10.1838 - y1_output_root_mean_squared_error: 2.6938 - y2_output_root_mean_squared_error: 3.2060 - val_loss: 23.5989 - val_y1_output_loss: 9.1869 - val_y2_output_loss: 13.6634 - val_y1_output_root_mean_squared_error: 3.0824 - val_y2_output_root_mean_squared_error: 3.7547
# Epoch 13/500
# 614/614 [==============================] - 0s 131us/sample - loss: 18.6694 - y1_output_loss: 7.2401 - y2_output_loss: 11.3132 - y1_output_root_mean_squared_error: 2.7000 - y2_output_root_mean_squared_error: 3.3734 - val_loss: 20.0639 - val_y1_output_loss: 8.1623 - val_y2_output_loss: 11.3474 - val_y1_output_root_mean_squared_error: 2.8986 - val_y2_output_root_mean_squared_error: 3.4150
# Epoch 14/500
# 614/614 [==============================] - 0s 130us/sample - loss: 19.8642 - y1_output_loss: 7.3119 - y2_output_loss: 12.5862 - y1_output_root_mean_squared_error: 2.7082 - y2_output_root_mean_squared_error: 3.5398 - val_loss: 18.1415 - val_y1_output_loss: 7.6908 - val_y2_output_loss: 9.9757 - val_y1_output_root_mean_squared_error: 2.8093 - val_y2_output_root_mean_squared_error: 3.2015
# Epoch 15/500
# 614/614 [==============================] - 0s 128us/sample - loss: 16.7046 - y1_output_loss: 6.9928 - y2_output_loss: 9.8617 - y1_output_root_mean_squared_error: 2.6159 - y2_output_root_mean_squared_error: 3.1403 - val_loss: 19.0367 - val_y1_output_loss: 7.3156 - val_y2_output_loss: 11.0752 - val_y1_output_root_mean_squared_error: 2.7496 - val_y2_output_root_mean_squared_error: 3.3877
# Epoch 16/500
# 614/614 [==============================] - 0s 135us/sample - loss: 17.5532 - y1_output_loss: 7.2409 - y2_output_loss: 10.2070 - y1_output_root_mean_squared_error: 2.6966 - y2_output_root_mean_squared_error: 3.2065 - val_loss: 17.9305 - val_y1_output_loss: 7.5414 - val_y2_output_loss: 9.7998 - val_y1_output_root_mean_squared_error: 2.7894 - val_y2_output_root_mean_squared_error: 3.1859
# Epoch 17/500
# 614/614 [==============================] - 0s 139us/sample - loss: 19.2465 - y1_output_loss: 7.0834 - y2_output_loss: 12.2733 - y1_output_root_mean_squared_error: 2.6615 - y2_output_root_mean_squared_error: 3.4875 - val_loss: 36.1660 - val_y1_output_loss: 11.1459 - val_y2_output_loss: 24.1414 - val_y1_output_root_mean_squared_error: 3.3875 - val_y2_output_root_mean_squared_error: 4.9690
# Epoch 18/500
# 614/614 [==============================] - 0s 154us/sample - loss: 20.3542 - y1_output_loss: 7.1381 - y2_output_loss: 13.2297 - y1_output_root_mean_squared_error: 2.6687 - y2_output_root_mean_squared_error: 3.6376 - val_loss: 19.1613 - val_y1_output_loss: 8.4777 - val_y2_output_loss: 10.0353 - val_y1_output_root_mean_squared_error: 2.9610 - val_y2_output_root_mean_squared_error: 3.2240
# Epoch 19/500
# 614/614 [==============================] - 0s 139us/sample - loss: 16.0312 - y1_output_loss: 5.9906 - y2_output_loss: 9.9832 - y1_output_root_mean_squared_error: 2.4578 - y2_output_root_mean_squared_error: 3.1607 - val_loss: 16.0996 - val_y1_output_loss: 6.3976 - val_y2_output_loss: 9.2678 - val_y1_output_root_mean_squared_error: 2.5687 - val_y2_output_root_mean_squared_error: 3.0824
# Epoch 20/500
# 614/614 [==============================] - 0s 140us/sample - loss: 17.6715 - y1_output_loss: 6.7425 - y2_output_loss: 10.9075 - y1_output_root_mean_squared_error: 2.5934 - y2_output_root_mean_squared_error: 3.3084 - val_loss: 24.4140 - val_y1_output_loss: 9.5556 - val_y2_output_loss: 14.0388 - val_y1_output_root_mean_squared_error: 3.1419 - val_y2_output_root_mean_squared_error: 3.8134
# Epoch 21/500
# 614/614 [==============================] - 0s 134us/sample - loss: 16.1393 - y1_output_loss: 6.0695 - y2_output_loss: 10.0323 - y1_output_root_mean_squared_error: 2.4730 - y2_output_root_mean_squared_error: 3.1660 - val_loss: 38.1096 - val_y1_output_loss: 9.2438 - val_y2_output_loss: 27.6766 - val_y1_output_root_mean_squared_error: 3.0933 - val_y2_output_root_mean_squared_error: 5.3424
# Epoch 22/500
# 614/614 [==============================] - 0s 141us/sample - loss: 16.3556 - y1_output_loss: 6.1339 - y2_output_loss: 10.0924 - y1_output_root_mean_squared_error: 2.4845 - y2_output_root_mean_squared_error: 3.1911 - val_loss: 15.4332 - val_y1_output_loss: 6.1188 - val_y2_output_loss: 8.8617 - val_y1_output_root_mean_squared_error: 2.5113 - val_y2_output_root_mean_squared_error: 3.0210
# Epoch 23/500
# 614/614 [==============================] - 0s 136us/sample - loss: 15.0530 - y1_output_loss: 5.6352 - y2_output_loss: 9.4877 - y1_output_root_mean_squared_error: 2.3664 - y2_output_root_mean_squared_error: 3.0746 - val_loss: 38.6817 - val_y1_output_loss: 10.0427 - val_y2_output_loss: 27.2533 - val_y1_output_root_mean_squared_error: 3.2260 - val_y2_output_root_mean_squared_error: 5.3174
# Epoch 24/500
# 614/614 [==============================] - 0s 130us/sample - loss: 17.6368 - y1_output_loss: 6.4514 - y2_output_loss: 11.3255 - y1_output_root_mean_squared_error: 2.5289 - y2_output_root_mean_squared_error: 3.3528 - val_loss: 41.1993 - val_y1_output_loss: 12.3567 - val_y2_output_loss: 27.6899 - val_y1_output_root_mean_squared_error: 3.5728 - val_y2_output_root_mean_squared_error: 5.3324
# Epoch 25/500
# 614/614 [==============================] - 0s 134us/sample - loss: 17.3309 - y1_output_loss: 6.2921 - y2_output_loss: 11.2334 - y1_output_root_mean_squared_error: 2.4874 - y2_output_root_mean_squared_error: 3.3382 - val_loss: 19.5654 - val_y1_output_loss: 7.5263 - val_y2_output_loss: 11.3772 - val_y1_output_root_mean_squared_error: 2.7890 - val_y2_output_root_mean_squared_error: 3.4332
# Epoch 26/500
# 614/614 [==============================] - 0s 132us/sample - loss: 14.2964 - y1_output_loss: 5.4837 - y2_output_loss: 8.8879 - y1_output_root_mean_squared_error: 2.3410 - y2_output_root_mean_squared_error: 2.9692 - val_loss: 32.4728 - val_y1_output_loss: 8.8292 - val_y2_output_loss: 22.5155 - val_y1_output_root_mean_squared_error: 3.0237 - val_y2_output_root_mean_squared_error: 4.8301
# Epoch 27/500
# 614/614 [==============================] - 0s 140us/sample - loss: 14.0927 - y1_output_loss: 5.5255 - y2_output_loss: 8.8465 - y1_output_root_mean_squared_error: 2.3272 - y2_output_root_mean_squared_error: 2.9457 - val_loss: 19.6977 - val_y1_output_loss: 6.7067 - val_y2_output_loss: 12.3295 - val_y1_output_root_mean_squared_error: 2.6333 - val_y2_output_root_mean_squared_error: 3.5726
# Epoch 28/500
# 614/614 [==============================] - 0s 134us/sample - loss: 13.0979 - y1_output_loss: 5.1567 - y2_output_loss: 7.9783 - y1_output_root_mean_squared_error: 2.2770 - y2_output_root_mean_squared_error: 2.8131 - val_loss: 31.7939 - val_y1_output_loss: 7.8015 - val_y2_output_loss: 22.9957 - val_y1_output_root_mean_squared_error: 2.8400 - val_y2_output_root_mean_squared_error: 4.8712
# Epoch 29/500
# 614/614 [==============================] - 0s 134us/sample - loss: 12.8171 - y1_output_loss: 4.8089 - y2_output_loss: 8.5623 - y1_output_root_mean_squared_error: 2.1640 - y2_output_root_mean_squared_error: 2.8521 - val_loss: 46.4903 - val_y1_output_loss: 11.8663 - val_y2_output_loss: 32.9636 - val_y1_output_root_mean_squared_error: 3.5075 - val_y2_output_root_mean_squared_error: 5.8470
# Epoch 30/500
# 614/614 [==============================] - 0s 142us/sample - loss: 15.2816 - y1_output_loss: 5.3193 - y2_output_loss: 9.8533 - y1_output_root_mean_squared_error: 2.3157 - y2_output_root_mean_squared_error: 3.1495 - val_loss: 19.0929 - val_y1_output_loss: 7.0212 - val_y2_output_loss: 11.5031 - val_y1_output_root_mean_squared_error: 2.6940 - val_y2_output_root_mean_squared_error: 3.4403
# Epoch 31/500
# 614/614 [==============================] - 0s 132us/sample - loss: 10.6447 - y1_output_loss: 4.2481 - y2_output_loss: 6.2991 - y1_output_root_mean_squared_error: 2.0711 - y2_output_root_mean_squared_error: 2.5210 - val_loss: 10.7762 - val_y1_output_loss: 4.0336 - val_y2_output_loss: 6.4229 - val_y1_output_root_mean_squared_error: 2.0395 - val_y2_output_root_mean_squared_error: 2.5723
# Epoch 32/500
# 614/614 [==============================] - 0s 131us/sample - loss: 11.0158 - y1_output_loss: 4.2504 - y2_output_loss: 6.7297 - y1_output_root_mean_squared_error: 2.0696 - y2_output_root_mean_squared_error: 2.5947 - val_loss: 15.6318 - val_y1_output_loss: 4.5333 - val_y2_output_loss: 10.7725 - val_y1_output_root_mean_squared_error: 2.1580 - val_y2_output_root_mean_squared_error: 3.3128
# Epoch 33/500
# 614/614 [==============================] - 0s 131us/sample - loss: 11.7355 - y1_output_loss: 4.0531 - y2_output_loss: 7.6772 - y1_output_root_mean_squared_error: 2.0170 - y2_output_root_mean_squared_error: 2.7690 - val_loss: 11.8782 - val_y1_output_loss: 3.8925 - val_y2_output_loss: 7.6428 - val_y1_output_root_mean_squared_error: 2.0003 - val_y2_output_root_mean_squared_error: 2.8066
# Epoch 34/500
# 614/614 [==============================] - 0s 140us/sample - loss: 10.8114 - y1_output_loss: 3.8620 - y2_output_loss: 6.9639 - y1_output_root_mean_squared_error: 1.9517 - y2_output_root_mean_squared_error: 2.6461 - val_loss: 13.1146 - val_y1_output_loss: 4.7827 - val_y2_output_loss: 7.9112 - val_y1_output_root_mean_squared_error: 2.2220 - val_y2_output_root_mean_squared_error: 2.8596
# Epoch 35/500
# 614/614 [==============================] - 0s 139us/sample - loss: 11.7607 - y1_output_loss: 4.4446 - y2_output_loss: 7.2556 - y1_output_root_mean_squared_error: 2.1110 - y2_output_root_mean_squared_error: 2.7027 - val_loss: 10.0726 - val_y1_output_loss: 3.4235 - val_y2_output_loss: 6.3503 - val_y1_output_root_mean_squared_error: 1.8760 - val_y2_output_root_mean_squared_error: 2.5599
# Epoch 36/500
# 614/614 [==============================] - 0s 139us/sample - loss: 11.0591 - y1_output_loss: 3.8002 - y2_output_loss: 7.2505 - y1_output_root_mean_squared_error: 1.9508 - y2_output_root_mean_squared_error: 2.6932 - val_loss: 15.1702 - val_y1_output_loss: 5.4586 - val_y2_output_loss: 9.2361 - val_y1_output_root_mean_squared_error: 2.3739 - val_y2_output_root_mean_squared_error: 3.0879
# Epoch 37/500
# 614/614 [==============================] - 0s 139us/sample - loss: 9.3907 - y1_output_loss: 3.5196 - y2_output_loss: 5.7887 - y1_output_root_mean_squared_error: 1.8849 - y2_output_root_mean_squared_error: 2.4162 - val_loss: 11.4576 - val_y1_output_loss: 3.5648 - val_y2_output_loss: 7.6105 - val_y1_output_root_mean_squared_error: 1.9161 - val_y2_output_root_mean_squared_error: 2.7903
# Epoch 38/500
# 614/614 [==============================] - 0s 146us/sample - loss: 9.8257 - y1_output_loss: 3.4671 - y2_output_loss: 6.2880 - y1_output_root_mean_squared_error: 1.8659 - y2_output_root_mean_squared_error: 2.5188 - val_loss: 8.1230 - val_y1_output_loss: 3.1717 - val_y2_output_loss: 4.7180 - val_y1_output_root_mean_squared_error: 1.8055 - val_y2_output_root_mean_squared_error: 2.2053
# Epoch 39/500
# 614/614 [==============================] - 0s 145us/sample - loss: 8.5720 - y1_output_loss: 3.0568 - y2_output_loss: 5.4693 - y1_output_root_mean_squared_error: 1.7498 - y2_output_root_mean_squared_error: 2.3474 - val_loss: 8.4895 - val_y1_output_loss: 3.0448 - val_y2_output_loss: 5.1869 - val_y1_output_root_mean_squared_error: 1.7713 - val_y2_output_root_mean_squared_error: 2.3134
# Epoch 40/500
# 614/614 [==============================] - 0s 140us/sample - loss: 13.8466 - y1_output_loss: 4.3071 - y2_output_loss: 9.4176 - y1_output_root_mean_squared_error: 2.0842 - y2_output_root_mean_squared_error: 3.0827 - val_loss: 8.0907 - val_y1_output_loss: 2.8374 - val_y2_output_loss: 4.9954 - val_y1_output_root_mean_squared_error: 1.7085 - val_y2_output_root_mean_squared_error: 2.2742
# Epoch 41/500
# 614/614 [==============================] - 0s 147us/sample - loss: 8.9481 - y1_output_loss: 3.2943 - y2_output_loss: 5.6429 - y1_output_root_mean_squared_error: 1.8200 - y2_output_root_mean_squared_error: 2.3740 - val_loss: 17.4558 - val_y1_output_loss: 4.3766 - val_y2_output_loss: 12.4971 - val_y1_output_root_mean_squared_error: 2.1237 - val_y2_output_root_mean_squared_error: 3.5980
# Epoch 42/500
# 614/614 [==============================] - 0s 135us/sample - loss: 10.9176 - y1_output_loss: 3.5564 - y2_output_loss: 7.3233 - y1_output_root_mean_squared_error: 1.8898 - y2_output_root_mean_squared_error: 2.7104 - val_loss: 13.1468 - val_y1_output_loss: 5.8946 - val_y2_output_loss: 6.8379 - val_y1_output_root_mean_squared_error: 2.4684 - val_y2_output_root_mean_squared_error: 2.6559
# Epoch 43/500
# 614/614 [==============================] - 0s 135us/sample - loss: 7.2165 - y1_output_loss: 2.5191 - y2_output_loss: 4.6343 - y1_output_root_mean_squared_error: 1.5945 - y2_output_root_mean_squared_error: 2.1620 - val_loss: 8.1839 - val_y1_output_loss: 2.7186 - val_y2_output_loss: 5.2059 - val_y1_output_root_mean_squared_error: 1.6742 - val_y2_output_root_mean_squared_error: 2.3197
# Epoch 44/500
# 614/614 [==============================] - 0s 140us/sample - loss: 7.6563 - y1_output_loss: 2.7431 - y2_output_loss: 4.9161 - y1_output_root_mean_squared_error: 1.6565 - y2_output_root_mean_squared_error: 2.2164 - val_loss: 8.0315 - val_y1_output_loss: 2.7251 - val_y2_output_loss: 5.0959 - val_y1_output_root_mean_squared_error: 1.6729 - val_y2_output_root_mean_squared_error: 2.2875
# Epoch 45/500
# 614/614 [==============================] - 0s 150us/sample - loss: 9.1316 - y1_output_loss: 3.0634 - y2_output_loss: 6.0465 - y1_output_root_mean_squared_error: 1.7493 - y2_output_root_mean_squared_error: 2.4641 - val_loss: 11.5049 - val_y1_output_loss: 4.1124 - val_y2_output_loss: 7.0252 - val_y1_output_root_mean_squared_error: 2.0619 - val_y2_output_root_mean_squared_error: 2.6932
# Epoch 46/500
# 614/614 [==============================] - 0s 143us/sample - loss: 7.2746 - y1_output_loss: 2.5907 - y2_output_loss: 4.6789 - y1_output_root_mean_squared_error: 1.6020 - y2_output_root_mean_squared_error: 2.1698 - val_loss: 7.3069 - val_y1_output_loss: 2.5133 - val_y2_output_loss: 4.5862 - val_y1_output_root_mean_squared_error: 1.6066 - val_y2_output_root_mean_squared_error: 2.1739
# Epoch 47/500
# 614/614 [==============================] - 0s 134us/sample - loss: 7.9971 - y1_output_loss: 2.7363 - y2_output_loss: 5.2624 - y1_output_root_mean_squared_error: 1.6486 - y2_output_root_mean_squared_error: 2.2977 - val_loss: 9.4818 - val_y1_output_loss: 3.5144 - val_y2_output_loss: 5.7139 - val_y1_output_root_mean_squared_error: 1.9004 - val_y2_output_root_mean_squared_error: 2.4229
# Epoch 48/500
# 614/614 [==============================] - 0s 144us/sample - loss: 9.0492 - y1_output_loss: 3.2682 - y2_output_loss: 5.7955 - y1_output_root_mean_squared_error: 1.8124 - y2_output_root_mean_squared_error: 2.4009 - val_loss: 7.9111 - val_y1_output_loss: 2.7042 - val_y2_output_loss: 4.9596 - val_y1_output_root_mean_squared_error: 1.6671 - val_y2_output_root_mean_squared_error: 2.2654
# Epoch 49/500
# 614/614 [==============================] - 0s 132us/sample - loss: 8.8465 - y1_output_loss: 2.6621 - y2_output_loss: 6.1991 - y1_output_root_mean_squared_error: 1.6232 - y2_output_root_mean_squared_error: 2.4924 - val_loss: 21.2492 - val_y1_output_loss: 5.9489 - val_y2_output_loss: 14.5346 - val_y1_output_root_mean_squared_error: 2.4827 - val_y2_output_root_mean_squared_error: 3.8840
# Epoch 50/500
# 614/614 [==============================] - 0s 130us/sample - loss: 6.7097 - y1_output_loss: 2.2010 - y2_output_loss: 4.5049 - y1_output_root_mean_squared_error: 1.4871 - y2_output_root_mean_squared_error: 2.1209 - val_loss: 7.1641 - val_y1_output_loss: 2.4337 - val_y2_output_loss: 4.5241 - val_y1_output_root_mean_squared_error: 1.5774 - val_y2_output_root_mean_squared_error: 2.1624
# Epoch 51/500
# 614/614 [==============================] - 0s 136us/sample - loss: 7.6825 - y1_output_loss: 2.6162 - y2_output_loss: 5.0571 - y1_output_root_mean_squared_error: 1.6126 - y2_output_root_mean_squared_error: 2.2544 - val_loss: 7.1819 - val_y1_output_loss: 2.3162 - val_y2_output_loss: 4.6439 - val_y1_output_root_mean_squared_error: 1.5463 - val_y2_output_root_mean_squared_error: 2.1888
# Epoch 52/500
# 614/614 [==============================] - 0s 134us/sample - loss: 6.8659 - y1_output_loss: 2.4110 - y2_output_loss: 4.4031 - y1_output_root_mean_squared_error: 1.5589 - y2_output_root_mean_squared_error: 2.1061 - val_loss: 9.9086 - val_y1_output_loss: 3.5073 - val_y2_output_loss: 6.1872 - val_y1_output_root_mean_squared_error: 1.8842 - val_y2_output_root_mean_squared_error: 2.5216
# Epoch 53/500
# 614/614 [==============================] - 0s 129us/sample - loss: 6.4199 - y1_output_loss: 2.1870 - y2_output_loss: 4.2766 - y1_output_root_mean_squared_error: 1.4810 - y2_output_root_mean_squared_error: 2.0558 - val_loss: 11.9274 - val_y1_output_loss: 2.7706 - val_y2_output_loss: 8.7951 - val_y1_output_root_mean_squared_error: 1.6894 - val_y2_output_root_mean_squared_error: 3.0122
# Epoch 54/500
# 614/614 [==============================] - 0s 131us/sample - loss: 7.1522 - y1_output_loss: 2.3191 - y2_output_loss: 4.7707 - y1_output_root_mean_squared_error: 1.5291 - y2_output_root_mean_squared_error: 2.1941 - val_loss: 6.6488 - val_y1_output_loss: 2.1409 - val_y2_output_loss: 4.2989 - val_y1_output_root_mean_squared_error: 1.4841 - val_y2_output_root_mean_squared_error: 2.1086
# Epoch 55/500
# 614/614 [==============================] - 0s 128us/sample - loss: 7.2199 - y1_output_loss: 2.3821 - y2_output_loss: 4.8047 - y1_output_root_mean_squared_error: 1.5483 - y2_output_root_mean_squared_error: 2.1960 - val_loss: 7.7460 - val_y1_output_loss: 2.4098 - val_y2_output_loss: 5.0916 - val_y1_output_root_mean_squared_error: 1.5737 - val_y2_output_root_mean_squared_error: 2.2956
# Epoch 56/500
# 614/614 [==============================] - 0s 128us/sample - loss: 6.7375 - y1_output_loss: 2.3078 - y2_output_loss: 4.4043 - y1_output_root_mean_squared_error: 1.5261 - y2_output_root_mean_squared_error: 2.0996 - val_loss: 6.8197 - val_y1_output_loss: 1.8945 - val_y2_output_loss: 4.7343 - val_y1_output_root_mean_squared_error: 1.3946 - val_y2_output_root_mean_squared_error: 2.2079
# Epoch 57/500
# 614/614 [==============================] - 0s 129us/sample - loss: 6.5694 - y1_output_loss: 2.0650 - y2_output_loss: 4.5298 - y1_output_root_mean_squared_error: 1.4376 - y2_output_root_mean_squared_error: 2.1220 - val_loss: 6.8298 - val_y1_output_loss: 2.3363 - val_y2_output_loss: 4.2969 - val_y1_output_root_mean_squared_error: 1.5460 - val_y2_output_root_mean_squared_error: 2.1070
# Epoch 58/500
# 614/614 [==============================] - 0s 139us/sample - loss: 8.4959 - y1_output_loss: 2.6518 - y2_output_loss: 6.0750 - y1_output_root_mean_squared_error: 1.6051 - y2_output_root_mean_squared_error: 2.4330 - val_loss: 49.4400 - val_y1_output_loss: 15.7640 - val_y2_output_loss: 32.3726 - val_y1_output_root_mean_squared_error: 4.0165 - val_y2_output_root_mean_squared_error: 5.7713
# Epoch 59/500
# 614/614 [==============================] - 0s 138us/sample - loss: 8.0810 - y1_output_loss: 2.6069 - y2_output_loss: 5.4444 - y1_output_root_mean_squared_error: 1.6149 - y2_output_root_mean_squared_error: 2.3394 - val_loss: 11.2293 - val_y1_output_loss: 2.6412 - val_y2_output_loss: 8.2532 - val_y1_output_root_mean_squared_error: 1.6496 - val_y2_output_root_mean_squared_error: 2.9169
# Epoch 60/500
# 614/614 [==============================] - 0s 134us/sample - loss: 6.9809 - y1_output_loss: 2.3785 - y2_output_loss: 4.6169 - y1_output_root_mean_squared_error: 1.5484 - y2_output_root_mean_squared_error: 2.1409 - val_loss: 6.8560 - val_y1_output_loss: 2.1128 - val_y2_output_loss: 4.5621 - val_y1_output_root_mean_squared_error: 1.4694 - val_y2_output_root_mean_squared_error: 2.1672
# Epoch 61/500
# 614/614 [==============================] - 0s 125us/sample - loss: 6.8403 - y1_output_loss: 2.2748 - y2_output_loss: 4.5213 - y1_output_root_mean_squared_error: 1.5117 - y2_output_root_mean_squared_error: 2.1342 - val_loss: 11.8274 - val_y1_output_loss: 3.8293 - val_y2_output_loss: 7.6123 - val_y1_output_root_mean_squared_error: 1.9852 - val_y2_output_root_mean_squared_error: 2.8082
# Epoch 62/500
# 614/614 [==============================] - 0s 134us/sample - loss: 7.0511 - y1_output_loss: 2.1844 - y2_output_loss: 4.8624 - y1_output_root_mean_squared_error: 1.4817 - y2_output_root_mean_squared_error: 2.2036 - val_loss: 11.4949 - val_y1_output_loss: 3.4933 - val_y2_output_loss: 7.6169 - val_y1_output_root_mean_squared_error: 1.8975 - val_y2_output_root_mean_squared_error: 2.8097
# Epoch 63/500
# 614/614 [==============================] - 0s 133us/sample - loss: 6.4365 - y1_output_loss: 1.9687 - y2_output_loss: 4.4887 - y1_output_root_mean_squared_error: 1.4060 - y2_output_root_mean_squared_error: 2.1118 - val_loss: 6.8327 - val_y1_output_loss: 2.2479 - val_y2_output_loss: 4.3890 - val_y1_output_root_mean_squared_error: 1.5195 - val_y2_output_root_mean_squared_error: 2.1269
# Epoch 64/500
# 614/614 [==============================] - 0s 137us/sample - loss: 6.9198 - y1_output_loss: 2.1392 - y2_output_loss: 4.7743 - y1_output_root_mean_squared_error: 1.4612 - y2_output_root_mean_squared_error: 2.1874 - val_loss: 8.1031 - val_y1_output_loss: 2.3131 - val_y2_output_loss: 5.5917 - val_y1_output_root_mean_squared_error: 1.5393 - val_y2_output_root_mean_squared_error: 2.3945
# Epoch 65/500
# 614/614 [==============================] - 0s 128us/sample - loss: 5.1524 - y1_output_loss: 1.7083 - y2_output_loss: 3.4452 - y1_output_root_mean_squared_error: 1.3029 - y2_output_root_mean_squared_error: 1.8587 - val_loss: 10.0350 - val_y1_output_loss: 3.3175 - val_y2_output_loss: 6.4327 - val_y1_output_root_mean_squared_error: 1.8463 - val_y2_output_root_mean_squared_error: 2.5741
# Epoch 66/500
# 614/614 [==============================] - 0s 137us/sample - loss: 6.1612 - y1_output_loss: 2.0040 - y2_output_loss: 4.1124 - y1_output_root_mean_squared_error: 1.4200 - y2_output_root_mean_squared_error: 2.0359 - val_loss: 7.9129 - val_y1_output_loss: 2.4447 - val_y2_output_loss: 5.2304 - val_y1_output_root_mean_squared_error: 1.5863 - val_y2_output_root_mean_squared_error: 2.3230
# Epoch 67/500
# 614/614 [==============================] - 0s 129us/sample - loss: 6.0905 - y1_output_loss: 2.1941 - y2_output_loss: 3.8601 - y1_output_root_mean_squared_error: 1.4883 - y2_output_root_mean_squared_error: 1.9686 - val_loss: 7.0847 - val_y1_output_loss: 2.0906 - val_y2_output_loss: 4.8163 - val_y1_output_root_mean_squared_error: 1.4630 - val_y2_output_root_mean_squared_error: 2.2236
# Epoch 68/500
# 614/614 [==============================] - 0s 128us/sample - loss: 5.2825 - y1_output_loss: 1.6539 - y2_output_loss: 3.6687 - y1_output_root_mean_squared_error: 1.2790 - y2_output_root_mean_squared_error: 1.9096 - val_loss: 12.7734 - val_y1_output_loss: 2.4095 - val_y2_output_loss: 10.0429 - val_y1_output_root_mean_squared_error: 1.5732 - val_y2_output_root_mean_squared_error: 3.2091
# Epoch 69/500
# 614/614 [==============================] - 0s 133us/sample - loss: 6.1094 - y1_output_loss: 1.9310 - y2_output_loss: 4.1618 - y1_output_root_mean_squared_error: 1.3893 - y2_output_root_mean_squared_error: 2.0443 - val_loss: 7.5181 - val_y1_output_loss: 2.8475 - val_y2_output_loss: 4.4722 - val_y1_output_root_mean_squared_error: 1.7091 - val_y2_output_root_mean_squared_error: 2.1441
# Epoch 70/500
# 614/614 [==============================] - 0s 139us/sample - loss: 4.9420 - y1_output_loss: 1.5498 - y2_output_loss: 3.3529 - y1_output_root_mean_squared_error: 1.2508 - y2_output_root_mean_squared_error: 1.8378 - val_loss: 5.9161 - val_y1_output_loss: 1.6189 - val_y2_output_loss: 4.1226 - val_y1_output_root_mean_squared_error: 1.2861 - val_y2_output_root_mean_squared_error: 2.0645
# Epoch 71/500
# 614/614 [==============================] - 0s 130us/sample - loss: 4.3371 - y1_output_loss: 1.4734 - y2_output_loss: 2.8359 - y1_output_root_mean_squared_error: 1.2181 - y2_output_root_mean_squared_error: 1.6892 - val_loss: 5.6492 - val_y1_output_loss: 1.7922 - val_y2_output_loss: 3.6871 - val_y1_output_root_mean_squared_error: 1.3547 - val_y2_output_root_mean_squared_error: 1.9530
# Epoch 72/500
# 614/614 [==============================] - 0s 140us/sample - loss: 6.2124 - y1_output_loss: 2.0176 - y2_output_loss: 4.1684 - y1_output_root_mean_squared_error: 1.4248 - y2_output_root_mean_squared_error: 2.0450 - val_loss: 10.3364 - val_y1_output_loss: 3.0886 - val_y2_output_loss: 6.9662 - val_y1_output_root_mean_squared_error: 1.7787 - val_y2_output_root_mean_squared_error: 2.6782
# Epoch 73/500
# 614/614 [==============================] - 0s 129us/sample - loss: 7.2005 - y1_output_loss: 2.3940 - y2_output_loss: 4.8043 - y1_output_root_mean_squared_error: 1.5458 - y2_output_root_mean_squared_error: 2.1934 - val_loss: 5.3020 - val_y1_output_loss: 1.5673 - val_y2_output_loss: 3.5829 - val_y1_output_root_mean_squared_error: 1.2655 - val_y2_output_root_mean_squared_error: 1.9237
# Epoch 74/500
# 614/614 [==============================] - 0s 135us/sample - loss: 4.8222 - y1_output_loss: 1.4654 - y2_output_loss: 3.4300 - y1_output_root_mean_squared_error: 1.2113 - y2_output_root_mean_squared_error: 1.8316 - val_loss: 16.1802 - val_y1_output_loss: 2.9008 - val_y2_output_loss: 12.7359 - val_y1_output_root_mean_squared_error: 1.7272 - val_y2_output_root_mean_squared_error: 3.6328
# Epoch 75/500
# 614/614 [==============================] - 0s 132us/sample - loss: 4.6452 - y1_output_loss: 1.3770 - y2_output_loss: 3.2277 - y1_output_root_mean_squared_error: 1.1781 - y2_output_root_mean_squared_error: 1.8048 - val_loss: 4.0044 - val_y1_output_loss: 1.1142 - val_y2_output_loss: 2.7810 - val_y1_output_root_mean_squared_error: 1.0655 - val_y2_output_root_mean_squared_error: 1.6938
# Epoch 76/500
# 614/614 [==============================] - 0s 138us/sample - loss: 5.6869 - y1_output_loss: 1.6616 - y2_output_loss: 4.0505 - y1_output_root_mean_squared_error: 1.2808 - y2_output_root_mean_squared_error: 2.0116 - val_loss: 10.3242 - val_y1_output_loss: 2.8781 - val_y2_output_loss: 7.1084 - val_y1_output_root_mean_squared_error: 1.7207 - val_y2_output_root_mean_squared_error: 2.7136
# Epoch 77/500
# 614/614 [==============================] - 0s 128us/sample - loss: 4.6984 - y1_output_loss: 1.4921 - y2_output_loss: 3.1832 - y1_output_root_mean_squared_error: 1.2258 - y2_output_root_mean_squared_error: 1.7877 - val_loss: 8.7978 - val_y1_output_loss: 2.1771 - val_y2_output_loss: 6.3850 - val_y1_output_root_mean_squared_error: 1.4865 - val_y2_output_root_mean_squared_error: 2.5667
# Epoch 78/500
# 614/614 [==============================] - 0s 127us/sample - loss: 3.9478 - y1_output_loss: 1.1929 - y2_output_loss: 2.7422 - y1_output_root_mean_squared_error: 1.0932 - y2_output_root_mean_squared_error: 1.6591 - val_loss: 5.8550 - val_y1_output_loss: 1.2648 - val_y2_output_loss: 4.4081 - val_y1_output_root_mean_squared_error: 1.1361 - val_y2_output_root_mean_squared_error: 2.1364
# Epoch 79/500
# 614/614 [==============================] - 0s 135us/sample - loss: 3.3416 - y1_output_loss: 1.0534 - y2_output_loss: 2.2665 - y1_output_root_mean_squared_error: 1.0289 - y2_output_root_mean_squared_error: 1.5110 - val_loss: 6.4566 - val_y1_output_loss: 1.8266 - val_y2_output_loss: 4.4299 - val_y1_output_root_mean_squared_error: 1.3708 - val_y2_output_root_mean_squared_error: 2.1395
# Epoch 80/500
# 614/614 [==============================] - 0s 142us/sample - loss: 3.0885 - y1_output_loss: 0.9223 - y2_output_loss: 2.1420 - y1_output_root_mean_squared_error: 0.9649 - y2_output_root_mean_squared_error: 1.4688 - val_loss: 4.0108 - val_y1_output_loss: 1.0077 - val_y2_output_loss: 2.9206 - val_y1_output_root_mean_squared_error: 1.0050 - val_y2_output_root_mean_squared_error: 1.7323
# Epoch 81/500
# 614/614 [==============================] - 0s 135us/sample - loss: 3.0590 - y1_output_loss: 0.9104 - y2_output_loss: 2.1319 - y1_output_root_mean_squared_error: 0.9545 - y2_output_root_mean_squared_error: 1.4656 - val_loss: 4.1461 - val_y1_output_loss: 1.2408 - val_y2_output_loss: 2.8241 - val_y1_output_root_mean_squared_error: 1.1204 - val_y2_output_root_mean_squared_error: 1.7002
# Epoch 82/500
# 614/614 [==============================] - 0s 129us/sample - loss: 3.9822 - y1_output_loss: 1.1921 - y2_output_loss: 2.7780 - y1_output_root_mean_squared_error: 1.0962 - y2_output_root_mean_squared_error: 1.6675 - val_loss: 3.8325 - val_y1_output_loss: 1.0373 - val_y2_output_loss: 2.7389 - val_y1_output_root_mean_squared_error: 1.0177 - val_y2_output_root_mean_squared_error: 1.6723
# Epoch 83/500
# 614/614 [==============================] - 0s 133us/sample - loss: 3.3201 - y1_output_loss: 0.9925 - y2_output_loss: 2.3143 - y1_output_root_mean_squared_error: 0.9986 - y2_output_root_mean_squared_error: 1.5241 - val_loss: 4.3106 - val_y1_output_loss: 0.8888 - val_y2_output_loss: 3.3526 - val_y1_output_root_mean_squared_error: 0.9420 - val_y2_output_root_mean_squared_error: 1.8502
# Epoch 84/500
# 614/614 [==============================] - 0s 128us/sample - loss: 3.6011 - y1_output_loss: 1.0240 - y2_output_loss: 2.5799 - y1_output_root_mean_squared_error: 1.0067 - y2_output_root_mean_squared_error: 1.6086 - val_loss: 6.5765 - val_y1_output_loss: 1.9887 - val_y2_output_loss: 4.3812 - val_y1_output_root_mean_squared_error: 1.4289 - val_y2_output_root_mean_squared_error: 2.1295
# Epoch 85/500
# 614/614 [==============================] - 0s 132us/sample - loss: 4.7670 - y1_output_loss: 1.3985 - y2_output_loss: 3.3813 - y1_output_root_mean_squared_error: 1.1854 - y2_output_root_mean_squared_error: 1.8335 - val_loss: 5.6824 - val_y1_output_loss: 1.2883 - val_y2_output_loss: 4.2491 - val_y1_output_root_mean_squared_error: 1.1388 - val_y2_output_root_mean_squared_error: 2.0942
# Epoch 86/500
# 614/614 [==============================] - 0s 131us/sample - loss: 2.7167 - y1_output_loss: 0.7242 - y2_output_loss: 1.9836 - y1_output_root_mean_squared_error: 0.8545 - y2_output_root_mean_squared_error: 1.4094 - val_loss: 6.2044 - val_y1_output_loss: 1.4490 - val_y2_output_loss: 4.6185 - val_y1_output_root_mean_squared_error: 1.2125 - val_y2_output_root_mean_squared_error: 2.1758
# Epoch 87/500
# 614/614 [==============================] - 0s 134us/sample - loss: 4.1158 - y1_output_loss: 1.0629 - y2_output_loss: 3.0532 - y1_output_root_mean_squared_error: 1.0258 - y2_output_root_mean_squared_error: 1.7503 - val_loss: 6.0718 - val_y1_output_loss: 1.4086 - val_y2_output_loss: 4.4908 - val_y1_output_root_mean_squared_error: 1.1962 - val_y2_output_root_mean_squared_error: 2.1543
# Epoch 88/500
# 614/614 [==============================] - 0s 141us/sample - loss: 5.1758 - y1_output_loss: 1.4504 - y2_output_loss: 3.6844 - y1_output_root_mean_squared_error: 1.2101 - y2_output_root_mean_squared_error: 1.9265 - val_loss: 3.6658 - val_y1_output_loss: 0.7680 - val_y2_output_loss: 2.7968 - val_y1_output_root_mean_squared_error: 0.8813 - val_y2_output_root_mean_squared_error: 1.6998
# Epoch 89/500
# 614/614 [==============================] - 0s 126us/sample - loss: 2.7758 - y1_output_loss: 0.6858 - y2_output_loss: 2.0761 - y1_output_root_mean_squared_error: 0.8283 - y2_output_root_mean_squared_error: 1.4456 - val_loss: 3.7456 - val_y1_output_loss: 0.9377 - val_y2_output_loss: 2.7313 - val_y1_output_root_mean_squared_error: 0.9684 - val_y2_output_root_mean_squared_error: 1.6757
# Epoch 90/500
# 614/614 [==============================] - 0s 127us/sample - loss: 3.2623 - y1_output_loss: 0.8907 - y2_output_loss: 2.3907 - y1_output_root_mean_squared_error: 0.9467 - y2_output_root_mean_squared_error: 1.5382 - val_loss: 15.2341 - val_y1_output_loss: 2.8093 - val_y2_output_loss: 12.0099 - val_y1_output_root_mean_squared_error: 1.6976 - val_y2_output_root_mean_squared_error: 3.5146
# Epoch 91/500
# 614/614 [==============================] - 0s 130us/sample - loss: 3.0332 - y1_output_loss: 0.8034 - y2_output_loss: 2.2476 - y1_output_root_mean_squared_error: 0.8886 - y2_output_root_mean_squared_error: 1.4979 - val_loss: 10.3168 - val_y1_output_loss: 2.6953 - val_y2_output_loss: 7.3115 - val_y1_output_root_mean_squared_error: 1.6595 - val_y2_output_root_mean_squared_error: 2.7501
# Epoch 92/500
# 614/614 [==============================] - 0s 129us/sample - loss: 4.9056 - y1_output_loss: 1.2629 - y2_output_loss: 3.6114 - y1_output_root_mean_squared_error: 1.1281 - y2_output_root_mean_squared_error: 1.9060 - val_loss: 3.7804 - val_y1_output_loss: 0.7671 - val_y2_output_loss: 2.9208 - val_y1_output_root_mean_squared_error: 0.8761 - val_y2_output_root_mean_squared_error: 1.7358
# Epoch 93/500
# 614/614 [==============================] - 0s 128us/sample - loss: 3.9571 - y1_output_loss: 1.0259 - y2_output_loss: 2.9101 - y1_output_root_mean_squared_error: 1.0140 - y2_output_root_mean_squared_error: 1.7114 - val_loss: 7.1155 - val_y1_output_loss: 1.8473 - val_y2_output_loss: 5.0402 - val_y1_output_root_mean_squared_error: 1.3775 - val_y2_output_root_mean_squared_error: 2.2843
# Epoch 94/500
# 614/614 [==============================] - 0s 126us/sample - loss: 3.2115 - y1_output_loss: 0.7976 - y2_output_loss: 2.3842 - y1_output_root_mean_squared_error: 0.8970 - y2_output_root_mean_squared_error: 1.5514 - val_loss: 6.0819 - val_y1_output_loss: 1.9971 - val_y2_output_loss: 3.9467 - val_y1_output_root_mean_squared_error: 1.4236 - val_y2_output_root_mean_squared_error: 2.0138
# Epoch 95/500
# 614/614 [==============================] - 0s 132us/sample - loss: 2.9263 - y1_output_loss: 0.8277 - y2_output_loss: 2.1310 - y1_output_root_mean_squared_error: 0.9104 - y2_output_root_mean_squared_error: 1.4483 - val_loss: 12.0939 - val_y1_output_loss: 1.0593 - val_y2_output_loss: 10.7373 - val_y1_output_root_mean_squared_error: 1.0368 - val_y2_output_root_mean_squared_error: 3.3195
# Epoch 96/500
# 614/614 [==============================] - 0s 132us/sample - loss: 2.2298 - y1_output_loss: 0.5815 - y2_output_loss: 1.6318 - y1_output_root_mean_squared_error: 0.7656 - y2_output_root_mean_squared_error: 1.2821 - val_loss: 4.1891 - val_y1_output_loss: 0.8943 - val_y2_output_loss: 3.1890 - val_y1_output_root_mean_squared_error: 0.9492 - val_y2_output_root_mean_squared_error: 1.8133
# Epoch 97/500
# 614/614 [==============================] - 0s 129us/sample - loss: 2.3165 - y1_output_loss: 0.6224 - y2_output_loss: 1.7421 - y1_output_root_mean_squared_error: 0.7800 - y2_output_root_mean_squared_error: 1.3069 - val_loss: 6.0182 - val_y1_output_loss: 1.6535 - val_y2_output_loss: 4.2226 - val_y1_output_root_mean_squared_error: 1.2947 - val_y2_output_root_mean_squared_error: 2.0837
# Epoch 98/500
# 614/614 [==============================] - 0s 127us/sample - loss: 2.9908 - y1_output_loss: 0.7521 - y2_output_loss: 2.2454 - y1_output_root_mean_squared_error: 0.8620 - y2_output_root_mean_squared_error: 1.4992 - val_loss: 5.5675 - val_y1_output_loss: 1.3489 - val_y2_output_loss: 4.1532 - val_y1_output_root_mean_squared_error: 1.1540 - val_y2_output_root_mean_squared_error: 2.0581
# Epoch 99/500
# 614/614 [==============================] - 0s 125us/sample - loss: 2.8327 - y1_output_loss: 0.6988 - y2_output_loss: 2.1801 - y1_output_root_mean_squared_error: 0.8291 - y2_output_root_mean_squared_error: 1.4647 - val_loss: 14.5726 - val_y1_output_loss: 4.6531 - val_y2_output_loss: 9.5042 - val_y1_output_root_mean_squared_error: 2.1887 - val_y2_output_root_mean_squared_error: 3.1276
# Epoch 100/500
# 614/614 [==============================] - 0s 134us/sample - loss: 4.8248 - y1_output_loss: 1.5097 - y2_output_loss: 3.3125 - y1_output_root_mean_squared_error: 1.2316 - y2_output_root_mean_squared_error: 1.8188 - val_loss: 3.4304 - val_y1_output_loss: 0.8098 - val_y2_output_loss: 2.5809 - val_y1_output_root_mean_squared_error: 0.8992 - val_y2_output_root_mean_squared_error: 1.6192
# Epoch 101/500
# 614/614 [==============================] - 0s 134us/sample - loss: 4.5476 - y1_output_loss: 1.3645 - y2_output_loss: 3.1552 - y1_output_root_mean_squared_error: 1.1729 - y2_output_root_mean_squared_error: 1.7810 - val_loss: 4.4718 - val_y1_output_loss: 0.6438 - val_y2_output_loss: 3.7092 - val_y1_output_root_mean_squared_error: 0.8066 - val_y2_output_root_mean_squared_error: 1.9548
# Epoch 102/500
# 614/614 [==============================] - 0s 134us/sample - loss: 2.8190 - y1_output_loss: 0.7510 - y2_output_loss: 2.1130 - y1_output_root_mean_squared_error: 0.8679 - y2_output_root_mean_squared_error: 1.4373 - val_loss: 5.9424 - val_y1_output_loss: 1.3592 - val_y2_output_loss: 4.4547 - val_y1_output_root_mean_squared_error: 1.1655 - val_y2_output_root_mean_squared_error: 2.1410
# Epoch 103/500
# 614/614 [==============================] - 0s 137us/sample - loss: 2.2969 - y1_output_loss: 0.6249 - y2_output_loss: 1.6809 - y1_output_root_mean_squared_error: 0.7877 - y2_output_root_mean_squared_error: 1.2947 - val_loss: 9.4224 - val_y1_output_loss: 2.3575 - val_y2_output_loss: 6.8984 - val_y1_output_root_mean_squared_error: 1.5465 - val_y2_output_root_mean_squared_error: 2.6516
# Epoch 104/500
# 614/614 [==============================] - 0s 137us/sample - loss: 2.9740 - y1_output_loss: 0.6839 - y2_output_loss: 2.2746 - y1_output_root_mean_squared_error: 0.8286 - y2_output_root_mean_squared_error: 1.5124 - val_loss: 3.1051 - val_y1_output_loss: 0.6490 - val_y2_output_loss: 2.3910 - val_y1_output_root_mean_squared_error: 0.8060 - val_y2_output_root_mean_squared_error: 1.5670
# Epoch 105/500
# 614/614 [==============================] - 0s 126us/sample - loss: 3.5643 - y1_output_loss: 0.8570 - y2_output_loss: 2.6769 - y1_output_root_mean_squared_error: 0.9298 - y2_output_root_mean_squared_error: 1.6431 - val_loss: 3.5058 - val_y1_output_loss: 0.8734 - val_y2_output_loss: 2.5401 - val_y1_output_root_mean_squared_error: 0.9414 - val_y2_output_root_mean_squared_error: 1.6185
# Epoch 106/500
# 614/614 [==============================] - 0s 129us/sample - loss: 2.7729 - y1_output_loss: 0.6845 - y2_output_loss: 2.1130 - y1_output_root_mean_squared_error: 0.8270 - y2_output_root_mean_squared_error: 1.4453 - val_loss: 5.6046 - val_y1_output_loss: 0.8510 - val_y2_output_loss: 4.6052 - val_y1_output_root_mean_squared_error: 0.9295 - val_y2_output_root_mean_squared_error: 2.1773
# Epoch 107/500
# 614/614 [==============================] - 0s 136us/sample - loss: 4.1289 - y1_output_loss: 0.9992 - y2_output_loss: 3.1108 - y1_output_root_mean_squared_error: 0.9978 - y2_output_root_mean_squared_error: 1.7701 - val_loss: 8.0366 - val_y1_output_loss: 1.9273 - val_y2_output_loss: 5.8921 - val_y1_output_root_mean_squared_error: 1.3999 - val_y2_output_root_mean_squared_error: 2.4651
# Epoch 108/500
# 614/614 [==============================] - 0s 139us/sample - loss: 2.3800 - y1_output_loss: 0.6156 - y2_output_loss: 1.7446 - y1_output_root_mean_squared_error: 0.7867 - y2_output_root_mean_squared_error: 1.3271 - val_loss: 2.8852 - val_y1_output_loss: 0.5900 - val_y2_output_loss: 2.2351 - val_y1_output_root_mean_squared_error: 0.7673 - val_y2_output_root_mean_squared_error: 1.5154
# Epoch 109/500
# 614/614 [==============================] - 0s 133us/sample - loss: 2.5391 - y1_output_loss: 0.6813 - y2_output_loss: 1.8468 - y1_output_root_mean_squared_error: 0.8228 - y2_output_root_mean_squared_error: 1.3646 - val_loss: 3.9171 - val_y1_output_loss: 0.7834 - val_y2_output_loss: 3.0985 - val_y1_output_root_mean_squared_error: 0.8688 - val_y2_output_root_mean_squared_error: 1.7783
# Epoch 110/500
# 614/614 [==============================] - 0s 132us/sample - loss: 2.0683 - y1_output_loss: 0.5198 - y2_output_loss: 1.6007 - y1_output_root_mean_squared_error: 0.7071 - y2_output_root_mean_squared_error: 1.2523 - val_loss: 33.2454 - val_y1_output_loss: 11.3638 - val_y2_output_loss: 20.8328 - val_y1_output_root_mean_squared_error: 3.4279 - val_y2_output_root_mean_squared_error: 4.6363
# Epoch 111/500
# 614/614 [==============================] - 0s 127us/sample - loss: 5.6025 - y1_output_loss: 1.6015 - y2_output_loss: 4.0038 - y1_output_root_mean_squared_error: 1.2659 - y2_output_root_mean_squared_error: 2.0000 - val_loss: 30.9785 - val_y1_output_loss: 9.9667 - val_y2_output_loss: 20.0907 - val_y1_output_root_mean_squared_error: 3.2044 - val_y2_output_root_mean_squared_error: 4.5509
# Epoch 112/500
# 614/614 [==============================] - 0s 129us/sample - loss: 2.5457 - y1_output_loss: 0.7237 - y2_output_loss: 1.8102 - y1_output_root_mean_squared_error: 0.8493 - y2_output_root_mean_squared_error: 1.3507 - val_loss: 8.0043 - val_y1_output_loss: 2.5540 - val_y2_output_loss: 5.2482 - val_y1_output_root_mean_squared_error: 1.6183 - val_y2_output_root_mean_squared_error: 2.3207
# Epoch 113/500
# 614/614 [==============================] - 0s 132us/sample - loss: 2.3886 - y1_output_loss: 0.6091 - y2_output_loss: 1.7595 - y1_output_root_mean_squared_error: 0.7835 - y2_output_root_mean_squared_error: 1.3322 - val_loss: 3.7574 - val_y1_output_loss: 1.0408 - val_y2_output_loss: 2.6204 - val_y1_output_root_mean_squared_error: 1.0281 - val_y2_output_root_mean_squared_error: 1.6433
# Epoch 114/500
# 614/614 [==============================] - 0s 128us/sample - loss: 2.7454 - y1_output_loss: 0.6078 - y2_output_loss: 2.4155 - y1_output_root_mean_squared_error: 0.7529 - y2_output_root_mean_squared_error: 1.4760 - val_loss: 38.4058 - val_y1_output_loss: 11.7039 - val_y2_output_loss: 25.8997 - val_y1_output_root_mean_squared_error: 3.4573 - val_y2_output_root_mean_squared_error: 5.1432
# Epoch 115/500
# 614/614 [==============================] - 0s 139us/sample - loss: 4.0171 - y1_output_loss: 1.2011 - y2_output_loss: 2.7957 - y1_output_root_mean_squared_error: 1.0995 - y2_output_root_mean_squared_error: 1.6758 - val_loss: 4.5424 - val_y1_output_loss: 0.9246 - val_y2_output_loss: 3.5402 - val_y1_output_root_mean_squared_error: 0.9563 - val_y2_output_root_mean_squared_error: 1.9047
# Epoch 116/500
# 614/614 [==============================] - 0s 128us/sample - loss: 2.1938 - y1_output_loss: 0.4848 - y2_output_loss: 1.7138 - y1_output_root_mean_squared_error: 0.6888 - y2_output_root_mean_squared_error: 1.3112 - val_loss: 2.9633 - val_y1_output_loss: 0.5442 - val_y2_output_loss: 2.3598 - val_y1_output_root_mean_squared_error: 0.7343 - val_y2_output_root_mean_squared_error: 1.5570
# Epoch 117/500
# 614/614 [==============================] - 0s 140us/sample - loss: 2.0248 - y1_output_loss: 0.4979 - y2_output_loss: 1.5133 - y1_output_root_mean_squared_error: 0.7068 - y2_output_root_mean_squared_error: 1.2350 - val_loss: 2.8184 - val_y1_output_loss: 0.4866 - val_y2_output_loss: 2.2642 - val_y1_output_root_mean_squared_error: 0.6954 - val_y2_output_root_mean_squared_error: 1.5280
# Epoch 118/500
# 614/614 [==============================] - 0s 138us/sample - loss: 2.6011 - y1_output_loss: 0.5829 - y2_output_loss: 2.0033 - y1_output_root_mean_squared_error: 0.7632 - y2_output_root_mean_squared_error: 1.4208 - val_loss: 4.7356 - val_y1_output_loss: 1.5043 - val_y2_output_loss: 3.1205 - val_y1_output_root_mean_squared_error: 1.2374 - val_y2_output_root_mean_squared_error: 1.7901
# Epoch 119/500
# 614/614 [==============================] - 0s 137us/sample - loss: 2.1744 - y1_output_loss: 0.4717 - y2_output_loss: 1.6918 - y1_output_root_mean_squared_error: 0.6875 - y2_output_root_mean_squared_error: 1.3045 - val_loss: 3.8001 - val_y1_output_loss: 0.6947 - val_y2_output_loss: 2.9992 - val_y1_output_root_mean_squared_error: 0.8378 - val_y2_output_root_mean_squared_error: 1.7602
# Epoch 120/500
# 614/614 [==============================] - 0s 137us/sample - loss: 2.0394 - y1_output_loss: 0.4926 - y2_output_loss: 1.5463 - y1_output_root_mean_squared_error: 0.7041 - y2_output_root_mean_squared_error: 1.2425 - val_loss: 3.3690 - val_y1_output_loss: 0.4663 - val_y2_output_loss: 2.8351 - val_y1_output_root_mean_squared_error: 0.6740 - val_y2_output_root_mean_squared_error: 1.7072
# ...
# Epoch 461/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.5099 - y1_output_loss: 0.1530 - y2_output_loss: 0.3564 - y1_output_root_mean_squared_error: 0.3904 - y2_output_root_mean_squared_error: 0.5979 - val_loss: 1.7849 - val_y1_output_loss: 0.2475 - val_y2_output_loss: 1.4993 - val_y1_output_root_mean_squared_error: 0.4837 - val_y2_output_root_mean_squared_error: 1.2454
# Epoch 462/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.3855 - y1_output_loss: 0.1105 - y2_output_loss: 0.2727 - y1_output_root_mean_squared_error: 0.3335 - y2_output_root_mean_squared_error: 0.5238 - val_loss: 1.4553 - val_y1_output_loss: 0.2412 - val_y2_output_loss: 1.1984 - val_y1_output_root_mean_squared_error: 0.4711 - val_y2_output_root_mean_squared_error: 1.1106
# Epoch 463/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.7540 - y1_output_loss: 0.1950 - y2_output_loss: 0.5555 - y1_output_root_mean_squared_error: 0.4420 - y2_output_root_mean_squared_error: 0.7474 - val_loss: 1.7041 - val_y1_output_loss: 0.2094 - val_y2_output_loss: 1.4575 - val_y1_output_root_mean_squared_error: 0.4449 - val_y2_output_root_mean_squared_error: 1.2272
# Epoch 464/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.4121 - y1_output_loss: 0.1158 - y2_output_loss: 0.2977 - y1_output_root_mean_squared_error: 0.3399 - y2_output_root_mean_squared_error: 0.5446 - val_loss: 1.5908 - val_y1_output_loss: 0.2408 - val_y2_output_loss: 1.3318 - val_y1_output_root_mean_squared_error: 0.4651 - val_y2_output_root_mean_squared_error: 1.1724
# Epoch 465/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.5403 - y1_output_loss: 0.1512 - y2_output_loss: 0.3849 - y1_output_root_mean_squared_error: 0.3903 - y2_output_root_mean_squared_error: 0.6228 - val_loss: 1.4006 - val_y1_output_loss: 0.1906 - val_y2_output_loss: 1.1917 - val_y1_output_root_mean_squared_error: 0.4160 - val_y2_output_root_mean_squared_error: 1.1079
# Epoch 466/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.3661 - y1_output_loss: 0.1187 - y2_output_loss: 0.2481 - y1_output_root_mean_squared_error: 0.3432 - y2_output_root_mean_squared_error: 0.4983 - val_loss: 1.8208 - val_y1_output_loss: 0.2006 - val_y2_output_loss: 1.5840 - val_y1_output_root_mean_squared_error: 0.4356 - val_y2_output_root_mean_squared_error: 1.2771
# Epoch 467/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.5949 - y1_output_loss: 0.1514 - y2_output_loss: 0.4465 - y1_output_root_mean_squared_error: 0.3887 - y2_output_root_mean_squared_error: 0.6662 - val_loss: 2.0604 - val_y1_output_loss: 0.2391 - val_y2_output_loss: 1.7887 - val_y1_output_root_mean_squared_error: 0.4611 - val_y2_output_root_mean_squared_error: 1.3593
# Epoch 468/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.4337 - y1_output_loss: 0.1364 - y2_output_loss: 0.2981 - y1_output_root_mean_squared_error: 0.3681 - y2_output_root_mean_squared_error: 0.5461 - val_loss: 1.5322 - val_y1_output_loss: 0.3812 - val_y2_output_loss: 1.1467 - val_y1_output_root_mean_squared_error: 0.5979 - val_y2_output_root_mean_squared_error: 1.0838
# Epoch 469/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.4358 - y1_output_loss: 0.1289 - y2_output_loss: 0.3041 - y1_output_root_mean_squared_error: 0.3602 - y2_output_root_mean_squared_error: 0.5533 - val_loss: 1.2293 - val_y1_output_loss: 0.2192 - val_y2_output_loss: 1.0186 - val_y1_output_root_mean_squared_error: 0.4339 - val_y2_output_root_mean_squared_error: 1.0203
# Epoch 470/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.3532 - y1_output_loss: 0.1070 - y2_output_loss: 0.2429 - y1_output_root_mean_squared_error: 0.3286 - y2_output_root_mean_squared_error: 0.4952 - val_loss: 1.5279 - val_y1_output_loss: 0.1874 - val_y2_output_loss: 1.3174 - val_y1_output_root_mean_squared_error: 0.4084 - val_y2_output_root_mean_squared_error: 1.1667
# Epoch 471/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.3663 - y1_output_loss: 0.1162 - y2_output_loss: 0.2521 - y1_output_root_mean_squared_error: 0.3353 - y2_output_root_mean_squared_error: 0.5039 - val_loss: 2.5356 - val_y1_output_loss: 0.4137 - val_y2_output_loss: 2.0755 - val_y1_output_root_mean_squared_error: 0.6292 - val_y2_output_root_mean_squared_error: 1.4628
# Epoch 472/500
# 614/614 [==============================] - 0s 156us/sample - loss: 0.4484 - y1_output_loss: 0.1299 - y2_output_loss: 0.3157 - y1_output_root_mean_squared_error: 0.3612 - y2_output_root_mean_squared_error: 0.5639 - val_loss: 1.4760 - val_y1_output_loss: 0.2598 - val_y2_output_loss: 1.1915 - val_y1_output_root_mean_squared_error: 0.4952 - val_y2_output_root_mean_squared_error: 1.1094
# Epoch 473/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.5553 - y1_output_loss: 0.1554 - y2_output_loss: 0.4256 - y1_output_root_mean_squared_error: 0.3774 - y2_output_root_mean_squared_error: 0.6426 - val_loss: 7.5851 - val_y1_output_loss: 1.8435 - val_y2_output_loss: 5.5371 - val_y1_output_root_mean_squared_error: 1.3707 - val_y2_output_root_mean_squared_error: 2.3888
# Epoch 474/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.4326 - y1_output_loss: 0.1361 - y2_output_loss: 0.2956 - y1_output_root_mean_squared_error: 0.3698 - y2_output_root_mean_squared_error: 0.5440 - val_loss: 1.8939 - val_y1_output_loss: 0.3007 - val_y2_output_loss: 1.5667 - val_y1_output_root_mean_squared_error: 0.5306 - val_y2_output_root_mean_squared_error: 1.2698
# Epoch 475/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.3121 - y1_output_loss: 0.1040 - y2_output_loss: 0.2059 - y1_output_root_mean_squared_error: 0.3235 - y2_output_root_mean_squared_error: 0.4554 - val_loss: 1.3351 - val_y1_output_loss: 0.1852 - val_y2_output_loss: 1.1343 - val_y1_output_root_mean_squared_error: 0.4073 - val_y2_output_root_mean_squared_error: 1.0813
# Epoch 476/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.9300 - y1_output_loss: 0.2045 - y2_output_loss: 0.7176 - y1_output_root_mean_squared_error: 0.4544 - y2_output_root_mean_squared_error: 0.8507 - val_loss: 2.4901 - val_y1_output_loss: 0.6541 - val_y2_output_loss: 1.7672 - val_y1_output_root_mean_squared_error: 0.8134 - val_y2_output_root_mean_squared_error: 1.3522
# Epoch 477/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.5054 - y1_output_loss: 0.1369 - y2_output_loss: 0.3651 - y1_output_root_mean_squared_error: 0.3715 - y2_output_root_mean_squared_error: 0.6062 - val_loss: 1.6159 - val_y1_output_loss: 0.2790 - val_y2_output_loss: 1.3171 - val_y1_output_root_mean_squared_error: 0.5132 - val_y2_output_root_mean_squared_error: 1.1630
# Epoch 478/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.3695 - y1_output_loss: 0.1130 - y2_output_loss: 0.2543 - y1_output_root_mean_squared_error: 0.3375 - y2_output_root_mean_squared_error: 0.5055 - val_loss: 1.2382 - val_y1_output_loss: 0.2256 - val_y2_output_loss: 1.0178 - val_y1_output_root_mean_squared_error: 0.4418 - val_y2_output_root_mean_squared_error: 1.0213
# Epoch 479/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.4663 - y1_output_loss: 0.1361 - y2_output_loss: 0.3275 - y1_output_root_mean_squared_error: 0.3700 - y2_output_root_mean_squared_error: 0.5739 - val_loss: 1.9246 - val_y1_output_loss: 0.2616 - val_y2_output_loss: 1.6335 - val_y1_output_root_mean_squared_error: 0.4934 - val_y2_output_root_mean_squared_error: 1.2966
# Epoch 480/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.5060 - y1_output_loss: 0.1327 - y2_output_loss: 0.3883 - y1_output_root_mean_squared_error: 0.3581 - y2_output_root_mean_squared_error: 0.6147 - val_loss: 9.8870 - val_y1_output_loss: 2.3658 - val_y2_output_loss: 7.2444 - val_y1_output_root_mean_squared_error: 1.5532 - val_y2_output_root_mean_squared_error: 2.7340
# Epoch 481/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.6673 - y1_output_loss: 0.2024 - y2_output_loss: 0.4590 - y1_output_root_mean_squared_error: 0.4519 - y2_output_root_mean_squared_error: 0.6805 - val_loss: 1.3952 - val_y1_output_loss: 0.2085 - val_y2_output_loss: 1.1741 - val_y1_output_root_mean_squared_error: 0.4313 - val_y2_output_root_mean_squared_error: 1.0996
# Epoch 482/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.3954 - y1_output_loss: 0.1132 - y2_output_loss: 0.2840 - y1_output_root_mean_squared_error: 0.3350 - y2_output_root_mean_squared_error: 0.5321 - val_loss: 1.7117 - val_y1_output_loss: 0.2260 - val_y2_output_loss: 1.4522 - val_y1_output_root_mean_squared_error: 0.4581 - val_y2_output_root_mean_squared_error: 1.2255
# Epoch 483/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.4074 - y1_output_loss: 0.1198 - y2_output_loss: 0.2863 - y1_output_root_mean_squared_error: 0.3456 - y2_output_root_mean_squared_error: 0.5366 - val_loss: 1.4442 - val_y1_output_loss: 0.2473 - val_y2_output_loss: 1.1737 - val_y1_output_root_mean_squared_error: 0.4824 - val_y2_output_root_mean_squared_error: 1.1007
# Epoch 484/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.4549 - y1_output_loss: 0.1399 - y2_output_loss: 0.3296 - y1_output_root_mean_squared_error: 0.3671 - y2_output_root_mean_squared_error: 0.5658 - val_loss: 3.5477 - val_y1_output_loss: 1.0008 - val_y2_output_loss: 2.4988 - val_y1_output_root_mean_squared_error: 1.0009 - val_y2_output_root_mean_squared_error: 1.5956
# Epoch 485/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.4942 - y1_output_loss: 0.1404 - y2_output_loss: 0.3507 - y1_output_root_mean_squared_error: 0.3758 - y2_output_root_mean_squared_error: 0.5941 - val_loss: 1.2738 - val_y1_output_loss: 0.1783 - val_y2_output_loss: 1.0752 - val_y1_output_root_mean_squared_error: 0.4055 - val_y2_output_root_mean_squared_error: 1.0533
# Epoch 486/500
# 614/614 [==============================] - 0s 139us/sample - loss: 0.3767 - y1_output_loss: 0.1140 - y2_output_loss: 0.2609 - y1_output_root_mean_squared_error: 0.3386 - y2_output_root_mean_squared_error: 0.5119 - val_loss: 1.2280 - val_y1_output_loss: 0.1818 - val_y2_output_loss: 1.0380 - val_y1_output_root_mean_squared_error: 0.4033 - val_y2_output_root_mean_squared_error: 1.0322
# Epoch 487/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.4135 - y1_output_loss: 0.1068 - y2_output_loss: 0.3041 - y1_output_root_mean_squared_error: 0.3279 - y2_output_root_mean_squared_error: 0.5531 - val_loss: 1.3346 - val_y1_output_loss: 0.1790 - val_y2_output_loss: 1.1396 - val_y1_output_root_mean_squared_error: 0.3995 - val_y2_output_root_mean_squared_error: 1.0840
# Epoch 488/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.3860 - y1_output_loss: 0.1068 - y2_output_loss: 0.2784 - y1_output_root_mean_squared_error: 0.3263 - y2_output_root_mean_squared_error: 0.5287 - val_loss: 1.4500 - val_y1_output_loss: 0.2436 - val_y2_output_loss: 1.1855 - val_y1_output_root_mean_squared_error: 0.4747 - val_y2_output_root_mean_squared_error: 1.1066
# Epoch 489/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.4623 - y1_output_loss: 0.1420 - y2_output_loss: 0.3180 - y1_output_root_mean_squared_error: 0.3766 - y2_output_root_mean_squared_error: 0.5661 - val_loss: 1.4438 - val_y1_output_loss: 0.2873 - val_y2_output_loss: 1.1418 - val_y1_output_root_mean_squared_error: 0.5167 - val_y2_output_root_mean_squared_error: 1.0848
# Epoch 490/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.3589 - y1_output_loss: 0.1190 - y2_output_loss: 0.2430 - y1_output_root_mean_squared_error: 0.3438 - y2_output_root_mean_squared_error: 0.4906 - val_loss: 2.2878 - val_y1_output_loss: 0.4343 - val_y2_output_loss: 1.7963 - val_y1_output_root_mean_squared_error: 0.6546 - val_y2_output_root_mean_squared_error: 1.3636
# Epoch 491/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.3743 - y1_output_loss: 0.1221 - y2_output_loss: 0.2503 - y1_output_root_mean_squared_error: 0.3505 - y2_output_root_mean_squared_error: 0.5014 - val_loss: 1.3350 - val_y1_output_loss: 0.2045 - val_y2_output_loss: 1.1145 - val_y1_output_root_mean_squared_error: 0.4323 - val_y2_output_root_mean_squared_error: 1.0715
# Epoch 492/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.3551 - y1_output_loss: 0.1105 - y2_output_loss: 0.2419 - y1_output_root_mean_squared_error: 0.3338 - y2_output_root_mean_squared_error: 0.4936 - val_loss: 1.2534 - val_y1_output_loss: 0.1944 - val_y2_output_loss: 1.0438 - val_y1_output_root_mean_squared_error: 0.4213 - val_y2_output_root_mean_squared_error: 1.0373
# Epoch 493/500
# 614/614 [==============================] - 0s 140us/sample - loss: 0.4015 - y1_output_loss: 0.1149 - y2_output_loss: 0.2842 - y1_output_root_mean_squared_error: 0.3400 - y2_output_root_mean_squared_error: 0.5347 - val_loss: 1.1651 - val_y1_output_loss: 0.1860 - val_y2_output_loss: 0.9667 - val_y1_output_root_mean_squared_error: 0.4095 - val_y2_output_root_mean_squared_error: 0.9987
# Epoch 494/500
# 614/614 [==============================] - 0s 140us/sample - loss: 0.4790 - y1_output_loss: 0.1323 - y2_output_loss: 0.3440 - y1_output_root_mean_squared_error: 0.3647 - y2_output_root_mean_squared_error: 0.5882 - val_loss: 1.9108 - val_y1_output_loss: 0.2403 - val_y2_output_loss: 1.6366 - val_y1_output_root_mean_squared_error: 0.4664 - val_y2_output_root_mean_squared_error: 1.3013
# Epoch 495/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.3364 - y1_output_loss: 0.0989 - y2_output_loss: 0.2382 - y1_output_root_mean_squared_error: 0.3142 - y2_output_root_mean_squared_error: 0.4875 - val_loss: 1.2944 - val_y1_output_loss: 0.1680 - val_y2_output_loss: 1.1018 - val_y1_output_root_mean_squared_error: 0.3945 - val_y2_output_root_mean_squared_error: 1.0671
# Epoch 496/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.3493 - y1_output_loss: 0.1089 - y2_output_loss: 0.2401 - y1_output_root_mean_squared_error: 0.3297 - y2_output_root_mean_squared_error: 0.4905 - val_loss: 1.7312 - val_y1_output_loss: 0.3366 - val_y2_output_loss: 1.3645 - val_y1_output_root_mean_squared_error: 0.5714 - val_y2_output_root_mean_squared_error: 1.1852
# Epoch 497/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.4985 - y1_output_loss: 0.1364 - y2_output_loss: 0.3581 - y1_output_root_mean_squared_error: 0.3706 - y2_output_root_mean_squared_error: 0.6010 - val_loss: 1.3502 - val_y1_output_loss: 0.1942 - val_y2_output_loss: 1.1360 - val_y1_output_root_mean_squared_error: 0.4221 - val_y2_output_root_mean_squared_error: 1.0826
# Epoch 498/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.4084 - y1_output_loss: 0.1312 - y2_output_loss: 0.2762 - y1_output_root_mean_squared_error: 0.3627 - y2_output_root_mean_squared_error: 0.5262 - val_loss: 1.3729 - val_y1_output_loss: 0.2469 - val_y2_output_loss: 1.1224 - val_y1_output_root_mean_squared_error: 0.4680 - val_y2_output_root_mean_squared_error: 1.0742
# Epoch 499/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.3320 - y1_output_loss: 0.1080 - y2_output_loss: 0.2220 - y1_output_root_mean_squared_error: 0.3297 - y2_output_root_mean_squared_error: 0.4725 - val_loss: 1.2921 - val_y1_output_loss: 0.2121 - val_y2_output_loss: 1.0757 - val_y1_output_root_mean_squared_error: 0.4307 - val_y2_output_root_mean_squared_error: 1.0520
# Epoch 500/500
# 614/614 [==============================] - 0s 143us/sample - loss: 0.4710 - y1_output_loss: 0.1231 - y2_output_loss: 0.3470 - y1_output_root_mean_squared_error: 0.3495 - y2_output_root_mean_squared_error: 0.5906 - val_loss: 1.2469 - val_y1_output_loss: 0.2245 - val_y2_output_loss: 1.0079 - val_y1_output_root_mean_squared_error: 0.4584 - val_y2_output_root_mean_squared_error: 1.0182

# %% [markdown]
# ## Evaluate the Model and Plot Metrics

# %%
# Test the model and print loss and mse for both outputs
loss, Y1_loss, Y2_loss, Y1_rmse, Y2_rmse = model.evaluate(x=norm_test_X, y=test_Y)
print("Loss = {}, Y1_loss = {}, Y1_mse = {}, Y2_loss = {}, Y2_mse = {}".format(loss, Y1_loss, Y1_rmse, Y2_loss, Y2_rmse))
# Out:
# 154/154 [==============================] - 0s 35us/sample - loss: 1.2469 - y1_output_loss: 0.2105 - y2_output_loss: 1.0153 - y1_output_root_mean_squared_error: 0.4584 - y2_output_root_mean_squared_error: 1.0182
# Loss = 1.2469451682908195, Y1_loss = 0.2104577273130417, Y1_mse = 0.45840346813201904, Y2_loss = 1.015317678451538, Y2_mse = 1.0182393789291382

# %%
# Plot the loss and mse
Y_pred = model.predict(norm_test_X)
plot_diff(test_Y[0], Y_pred[0], title='Y1')
plot_diff(test_Y[1], Y_pred[1], title='Y2')
plot_metrics(metric_name='y1_output_root_mean_squared_error', title='Y1 RMSE', ylim=6)
plot_metrics(metric_name='y2_output_root_mean_squared_error', title='Y2 RMSE', ylim=7)
